# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data

# %%
k = 4
eta = 0.01
sigma = 2.5
n_samples = 2000

# %%
from sklearn import datasets
two_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
X, y = two_moons

# %%
X.shape
# Out:
# (2000, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot()

for c in range(2):
    cluster_members = [X[i] for i in range(len(X)) if y[i] == c]    
    cluster_members = np.array(cluster_members)

    ax.scatter(cluster_members[:,0], cluster_members[:,1],  s= 0.5)

# %%
from graph_utils import *

# %%
A = knn_graph(X,knn=k)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-e92e25f3b59b> in <module>
# ----> 1 A = knn_graph(X,knn=k)
#
# /media/peratham/HDD/ml-techniques/clustering/graph_utils.py in knn_graph(X, knn)
#      32                 i0 = ind[0]
#      33                 for i in ind[1:]:
# ---> 34                         dist = distances[ind[0],i]
#      35                         A[ind[0], i] = dist
#      36                         A[i, ind[0]] = dist # by symmetry
#
# IndexError: index 280 is out of bounds for axis 1 with size 5

# %%
ni, nd = X.shape
nbrs = NearestNeighbors(n_neighbors=(knn+1), algorithm='ball_tree').fit(X)
distances, indices = nbrs.kneighbors(X)
